# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ### Seniment analysis on the clusters found with k-means

# %%
data = pd.read_csv("kmeans_clusters.csv",
                  encoding ='ISO-8859-1')

# %%
data.head(10)
# Out:
#    Unnamed: 0  Unnamed: 0.1           created_at  favorite_count  \
# 0           0             0  2016-12-30 22:18:18           84254
# 1           1             1  2016-12-30 19:46:55           25336
# 2           2             2  2016-12-30 19:41:33           97669
# 3           3             3  2016-12-29 14:54:21           45609
# 4           4             4  2016-12-28 22:06:28           51857
# 5           5             5  2016-12-28 14:25:11          117710
# 6           6             6  2016-12-28 14:19:46          106626
# 7           7             7  2016-12-28 14:07:13          117900
# 8           8             8  2016-12-28 03:10:07           78521
# 9           9             9  2016-12-27 21:52:29           99838
#
#                id_str  is_retweet  retweet_count               source  \
# 0  814958820980039680       False          23213  Twitter for Android
# 1  814920722208296960       False           7366   Twitter for iPhone
# 2  814919370711461888       False          34415  Twitter for Android
# 3  814484710025994240       False          11330   Twitter for iPhone
# 4  814231064847728640       False          13919   Twitter for iPhone
# 5  814114980983427072       False          34542  Twitter for Android
# 6  814113616110751744       False          30237  Twitter for Android
# 7  814110460761018368       False          31799  Twitter for Android
# 8  813945096269860864       False          19159  Twitter for Android
# 9  813865160163098624       False          23222  Twitter for Android
#
#                                                 text  \
# 0  Russians are playing @CNN and @NBCNews for suc...
# 1  Join @AmerIcan32, founded by Hall of Fame lege...
# 2  Great move on delay (by V. Putin) - I always k...
# 3  My Administration will follow two simple rules...
# 4  'Economists say Trump delivered hope' https://...
# 5  not anymore. The beginning of the end was the ...
# 6  We cannot continue to let Israel be treated wi...
# 7  Doing my best to disregard the many inflammato...
# 8  The U.S. Consumer Confidence Index for Decembe...
# 9  President Obama campaigned hard (and personall...
#
#                                              text_pp  label_kmeans
# 0                      fool funny watch clue totally             4
# 1                                   hall fame legend             0
# 2               move delay v putin always knew smart             0
# 3              administration follow two simple rule             0
# 4                                           say hope             9
# 5    beginning end horrible deal un stay strong fast             0
# 6   cannot continue let total disrespect used friend             2
# 7       best many statement thought going transition             0
# 8  consumer confidence nearly four point highest ...             0
# 9   hard personally important swing state lost voter             0

# %%
from nltk.sentiment.vader import SentimentIntensityAnalyzer
vader = SentimentIntensityAnalyzer()

# %%
vader.polarity_scores('cannot continue let total disrespect used friend')
# Out:
# {'compound': 0.1027, 'neg': 0.255, 'neu': 0.455, 'pos': 0.291}

# %%
vader.polarity_scores('We cannot continue to let Israel be treated with such total disdain and disrespect. They used to have a great friend in the U.S., but.......')
# Out:
# {'compound': 0.34, 'neg': 0.178, 'neu': 0.602, 'pos': 0.22}

# %%
data.iloc[6]
# Out:
# Unnamed: 0                                                        6
# Unnamed: 0.1                                                      6
# created_at                                      2016-12-28 14:19:46
# favorite_count                                               106626
# id_str                                           814113616110751744
# is_retweet                                                    False
# retweet_count                                                 30237
# source                                          Twitter for Android
# text              We cannot continue to let Israel be treated wi...
# text_pp            cannot continue let total disrespect used friend
# label_kmeans                                                      2
# Name: 6, dtype: object

# %%
data.loc[6]["text"]
# Out:
# 'We cannot continue to let Israel be treated with such total disdain and disrespect. They used to have a great friend in the U.S., but.......'

# %%
data.loc[6]["text_pp"]
# Out:
# 'cannot continue let total disrespect used friend'

# %%
text = data["text"]

# %%
text
# Out:
# 0       Russians are playing @CNN and @NBCNews for suc...
# 1       Join @AmerIcan32, founded by Hall of Fame lege...
# 2       Great move on delay (by V. Putin) - I always k...
# 3       My Administration will follow two simple rules...
# 4       'Economists say Trump delivered hope' https://...
# 5       not anymore. The beginning of the end was the ...
# 6       We cannot continue to let Israel be treated wi...
# 7       Doing my best to disregard the many inflammato...
# 8       The U.S. Consumer Confidence Index for Decembe...
# 9       President Obama campaigned hard (and personall...
# 10      The DJT Foundation, unlike most foundations, n...
# 11      I gave millions of dollars to DJT Foundation, ...
# 12      The world was gloomy before I won - there was ...
# 13      The United Nations has such great potential bu...
# 14      President Obama said that he thinks he would h...
# 15      Merry Christmas and a very, very, very , very ...
# 16                #MerryChristmas https://t.co/5GgDmJrGMS
# 17      .@FoxNews - "Objectified" tonight at 10:00 P.M...
# 18                Happy #Hanukkah https://t.co/UvZwtykV1E
# 19      The big loss yesterday for Israel in the Unite...
# 20      .@NBCNews purposely left out this part of my n...
# 21      Vladimir Putin said today about Hillary and De...
# 22      slaughter you. This is a purely religious thre...
# 23      The terrorist who killed so many people in Ger...
# 24      As to the U.N., things will be different after...
# 25      my presidency. Isn't this a ridiculous shame? ...
# 26      My wonderful son, Eric, will no longer be allo...
# 27      The so-called "A" list celebrities are all wan...
# 28      Based on the tremendous cost and cost overruns...
# 29      The United States must greatly strengthen and ...
#                               ...
# 3971    "@Granite_Hope: @brandonstinney How can you de...
# 3972    RT @EricTrump: So proud to be out on the campa...
# 3973    Just arrived in Mississippi for the rally. Wor...
# 3974    Heading to Biloxi, Mississippi. Massive crowds...
# 3975    Remember, I am self-funding my campaign, the o...
# 3976    When I look at all of the money the special in...
# 3977    I hope Bill Clinton starts talking about women...
# 3978    Hillary Clinton doesn't have the strength or s...
# 3979    Hillary Clinton said that it is O.K. to ban Mu...
# 3980    .@JebBush is a low energy "stiff" who should f...
# 3981    .@JebBush is a sad case. A total embarrassment...
# 3982    Massive crowds expected in Mississippi tomorro...
# 3983    #VoteTrump2016 &amp; together we will #MakeAme...
# 3984    Thank you so much to https://t.co/8OMryrUVET f...
# 3985    The person that Hillary Clinton least wants to...
# 3986    "@codyraymille: I have never been interested i...
# 3987    I will be going to Mississippi tomorrow night ...
# 3988    "@CASuperrunner: @georgehenryw Huckabee is a g...
# 3989    "@MEMEoryHead: I'm one of your biggest fans Mr...
# 3990    "@JodiL792: We are Standing with you! Spreadin...
# 3991    "@marie7777777777: @realDonaldTrump we love u ...
# 3992    Well, the year has officially begun. I have ma...
# 3993    "@sprinklermanus: @CNN @realDonaldTrump they'r...
# 3994    "@jallenaip: Hillary said she was in a "Fog of...
# 3995    Happy New Year from #MarALago! Thank you to my...
# 3996        #HappyNewYearAmerica! https://t.co/EeQb8PDrUe
# 3997    HAPPY NEW YEAR &amp; THANK YOU! https://t.co/Y...
# 3998    I will be on @FoxNews live,  with members of m...
# 3999    I would like to wish everyone A HAPPY AND HEAL...
# 4000    Do you believe that The State Department, on N...
# Name: text, Length: 4001, dtype: object

# %%
scores = list()
for i in text:
    scores.append(vader.polarity_scores(i)['compound'])

# %%
len(scores)
# Out:
# 4001

# %%
data['VADER_score'] = scores

# %%
data.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1           created_at  favorite_count  \
# 0           0             0  2016-12-30 22:18:18           84254
# 1           1             1  2016-12-30 19:46:55           25336
# 2           2             2  2016-12-30 19:41:33           97669
# 3           3             3  2016-12-29 14:54:21           45609
# 4           4             4  2016-12-28 22:06:28           51857
#
#                id_str  is_retweet  retweet_count               source  \
# 0  814958820980039680       False          23213  Twitter for Android
# 1  814920722208296960       False           7366   Twitter for iPhone
# 2  814919370711461888       False          34415  Twitter for Android
# 3  814484710025994240       False          11330   Twitter for iPhone
# 4  814231064847728640       False          13919   Twitter for iPhone
#
#                                                 text  \
# 0  Russians are playing @CNN and @NBCNews for suc...
# 1  Join @AmerIcan32, founded by Hall of Fame lege...
# 2  Great move on delay (by V. Putin) - I always k...
# 3  My Administration will follow two simple rules...
# 4  'Economists say Trump delivered hope' https://...
#
#                                  text_pp  label_kmeans  VADER_score
# 0          fool funny watch clue totally             4       0.2695
# 1                       hall fame legend             0       0.6249
# 2   move delay v putin always knew smart             0       0.7257
# 3  administration follow two simple rule             0       0.0000
# 4                               say hope             9       0.4404

# %%
#cluster 0 big cluster
cluster0 = data.loc[data['label_kmeans'] == 0]
cluster0.count()
cluster0.hist('VADER_score', bins = 50)
plt.savefig('VADER_bigcluster.png',bbox_inches="tight")
plt.title('Big cluster')
plt.show()

# %%
#cluster 1 nonsense
cluster1 = data.loc[data['label_kmeans'] == 1]
cluster1.count()
cluster1.hist('VADER_score', bins = 50)
plt.savefig('VADER_1nonsense.png',bbox_inches="tight")
plt.title('1 nonsense')
plt.show()

# %%
#cluster 2 america
cluster2 = data.loc[data['label_kmeans'] == 2]
cluster2.count()
cluster2.hist('VADER_score', bins = 50)
plt.savefig('VADER_america.png',bbox_inches="tight")
plt.title('America')
plt.show()

# %%
#cluster 3 hillary
cluster3 = data.loc[data['label_kmeans'] == 3]
cluster3.count()
cluster3.hist('VADER_score', bins = 50)
plt.savefig('VADER_hillary.png',bbox_inches="tight")
plt.title('Hillary')
plt.show()

# %%
cluster3.head()
# Out:
#     Unnamed: 0  Unnamed: 0.1           created_at  favorite_count  \
# 19          19            19  2016-12-24 21:33:27           83507
# 33          33            33  2016-12-21 13:29:38           82587
# 35          35            35  2016-12-21 13:15:14           68734
# 67          67            67  2016-12-13 11:57:35           77773
# 78          78            78  2016-12-12 01:02:14           72028
#
#                 id_str  is_retweet  retweet_count               source  \
# 19  812773204561379328       False          19826  Twitter for Android
# 33  811564284706689024       False          20374  Twitter for Android
# 35  811560662853939200       False          16033  Twitter for Android
# 67  808642018612310016       False          18233  Twitter for Android
# 78  808114703922843648       False          19928  Twitter for Android
#
#                                                  text  \
# 19  The big loss yesterday for Israel in the Unite...
# 33  I have not heard any of the pundits or comment...
# 35  Campaigning to win the Electoral College is mu...
# 67  Wisconsin and Pennsylvania have just certified...
# 78  Just watched @NBCNightlyNews - So biased, inac...
#
#                                               text_pp  label_kmeans  \
# 417   Major story that the Dems are making up phony ...
# 476   Just landed in Ohio. Thank you America- I am h...
# 605   ALL SAFE IN ORANGE COUNTY, NORTH CAROLINA. Wit...
# 681   RT @mike_pence: Congrats to my running mate @r...
# 847   I won the debate if you decide without watchin...
# 888   Such a great honor. Final debate polls are in ...
# 952   This is more than a campaign- it is a movement...
# 1055  Great honor to be endorsed by popular &amp; su...
# 1685  If I win the Presidency, we will swamp Justice...
# 1743  Raised a lot of money for the Republican Party...
# 1809  New Q poll out- we are going to win the whole ...
# 1993  As expected, the media is very much against me...
# 2016  I will be speaking about our great journey to ...
# 2025  I am getting bad marks from certain pundits be...
# 2076  Wow, USA Today did todays cover story on my re...
# 2093  I have raised/given a tremendous amount of mon...
# 2109  The Republican Party has to be smart &amp; str...
# 2344  .@KellyannePolls  Kellyanne, you were fantasti...
# 2362  I hear @JoeNBC of rapidly fading @Morning_Joe ...
# 2496  "@GreenSkyDeb: Look everybody, DonaldTrump wil...
# 2529  "@Trumptbird: Dear  I'm starting to believe th...
# 2538  "@Bubble709_: @realDonaldTrump Praying for you...
# 2668  Final #'s just announced in the GREAT State of...
# 2738  I want to thank @RealSheriffJoe for all of his...
# 2748  Much bigger win than anticipated in Arizona. T...
# 2812  Going to Salt Lake City, Utah, for a big rally...
# 2897  Thank you Kevin. With unification of the party...
# 3023  The phony lawsuit against Trump U could have b...
# 3048  "@JoeNBC: FOX calls Virginia for Trump. If it ...
# 3114  Fun to watch the Democrats working so hard to ...
# 3136  Have a good chance to win Texas on Tuesday. Cr...
# 3153  I'm going to do what @MittRomney was totally u...
# 3201  "@Vogelsong1: @EdRollins gets it. Was just on ...
# 3233  I am in Las Vegas, at the best hotel (by far),...
# 3235  A number of months ago, I was not expected to ...
# 3243  Thank you @SarahPalinUSA for your amazing help...
# 3246  People (pundits) gave me no chance in South Ca...
#
#                                                 text_pp  label_kmeans  \
# 35    win electoral college much difficult popular w...             3
# 152   state michigan certified win giving supporter ...             3
# 171   democrat incorrectly thought going win electio...             3
# 210   especially second third plus speech large rall...             3
# 213          governor state congratulate win incredible             3
# 214                   bush w express best wish win nice             3
# 215                          mitt congratulate win nice             3
# 218                        prove life unite win win win             3
# 237   going win state michigan going win back white ...             3
# 289                               north win going going             3
# 301            day going win state going win back white             3
# 317                good man help win congressional seat             3
# 328   legendary coach bobby knight win many champion...             3
# 417            major story making phony order going win             3
# 476                           landed win final movement             3
# 605       safe orange county north way never forget win             3
# 681                              running mate win stand             3
# 847   decide without watching totally one sided desp...             3
# 888                      honor final movement win first             3
# 952                          campaign movement sign win             3
# 1055  honor endorsed popular successful state much w...             3
# 1685  win presidency swamp justice real judge real l...             3
# 1743  raised lot money republican party figure morni...             3
# 1809                             q going win whole deal             3
# 1993           medium much amazing like win primary win             3
# 2016  speaking journey republican nomination movemen...             3
# 2025  getting bad mark certain pundit small campaign...             3
# 2076       wow cover story record lawsuit win loss want             3
# 2093  raised given tremendous amount money veteran g...             3
# 2109  republican party smart strong want win allow l...             3
# 2344                           fantastic keep going win             3
# 2362  hear rapidly pushing hard third party candidat...             3
# 2496  look everybody win first ballot keep praying t...             3
# 2529   dear starting believe actually going win primary             3
# 2538                            praying family win york             3
# 2668  final state mo win certified show increase lea...             3
# 2738      want help historic win could done without joe             3
# 2748                       much bigger win never forget             3
# 2812  going salt lake city rally ted win mormon like...             3
# 2897                       party republican win massive             3
# 3023  phony lawsuit could easily settled want go cou...             3
# 3048                fox call hold win setback win state             3
# 3114  fun watch democrat working hard win state sout...             3
# 3136  good chance win nasty guy one senate endorseme...             3
# 3153                           going totally unable win             3
# 3201                    explaining win general election             3
# 3233  la best hotel far international working wonder...             3
# 3235  number month ago win south ted yet landslide e...             3
# 3243         amazing help support win leaving south got             3
# 3246  pundit gave chance south look like possible wi...             3
#
#       VADER_score
# 35         0.8158
# 152        0.9641
# 171        0.7345
# 210        0.9268
# 213        0.9744
# 214        0.9183
# 215        0.8856
# 218        0.9501
# 237        0.9478
# 289        0.7644
# 301        0.9513
# 317        0.8737
# 328        0.8750
# 417        0.7027
# 476        0.8779
# 605        0.9098
# 681        0.8908
# 847        0.7761
# 888        0.9060
# 952        0.7027
# 1055       0.9499
# 1685       0.8398
# 1743       0.8588
# 1809       0.8728
# 1993       0.9531
# 2016       0.8602
# 2025       0.7345
# 2076       0.7269
# 2093       0.7661
# 2109       0.9027
# 2344       0.9263
# 2362       0.7964
# 2496       0.8154
# 2529       0.8139
# 2538       0.8439
# 2668       0.9209
# 2738       0.8622
# 2748       0.8052
# 2812       0.7431
# 2897       0.8478
# 3023       0.9423
# 3048       0.8225
# 3114       0.9606
# 3136       0.7356
# 3153       0.7027
# 3201       0.7574
# 3233       0.9290
# 3235       0.7752
# 3243       0.9412
# 3246       0.8777

# %%
data.loc[2076]["text"]
# Out:
# "Wow, USA Today did todays cover story on my record in lawsuits. Verdict: 450 wins, 38 losses. Isn't that what you want for your president?"

# %%
cluster3_neg = cluster3.loc[cluster3['VADER_score'] <-0.7]

# %%
cluster3_neg.head(10)
# Out:
#      Unnamed: 0  Unnamed: 0.1           created_at  favorite_count  \
# 155         155           155  2016-11-29 02:19:53           32567
# 216         216           216  2016-11-13 14:43:09           86992
# 323         327           327  2016-11-01 10:31:46           55584
# 422         426           426  2016-10-23 23:40:14           41150
# 499         503           503  2016-10-20 02:19:22           14918
# 671         677           677  2016-10-11 13:05:53           42510
# 677         683           683  2016-10-10 19:14:00           34322
# 750         756           756  2016-10-08 22:40:30               0
# 787         795           795  2016-10-05 02:17:30               0
# 858         866           866  2016-09-30 09:19:25           29597
#
#                  id_str  is_retweet  retweet_count               source  \
# 155  803423203620245504       False           7723  Twitter for Android
# 216  797812048805695488       False          22131  Twitter for Android
# 323  793400131525677056       False          21459  Twitter for Android
# 422  790337063489040384       False          16269  Twitter for Android
# 499  788927558288969728       False           6272   Twitter Web Client
# 671  785828772423561216       False          16799  Twitter for Android
# 677  785559022082658304       False          14451   Twitter for iPhone
# 750  784886214931390464        True          37047   Twitter for iPhone
# 787  783491271088156672        True           6022   Twitter for iPhone
# 858  781785509639118848       False          11510  Twitter for Android
#
#                                                   text  \
# 155  "@FiIibuster: @jeffzeleny Pathetic - you have ...
# 216  The @nytimes sent a letter to their subscriber...
# 323  Look at the way Crooked Hillary is handling th...
# 422  The attack on Mosul is turning out to be a tot...
# 499  Bernie Sanders on HRC: Bad Judgement. John Pod...
# 671  Our very weak and ineffective leader, Paul Rya...
# 677  CNN is the worst - fortunately they have bad r...
# 750  RT @atensnut: How many times must it be said? ...
# 787  RT @TeamTrump: Obama-Clinton FAILED foreign po...
# 858  Using Alicia M in the debate as a paragon of v...
#
#                                                text_pp  label_kmeans  \
# 155  pathetic evidence suffer voter fraud shame bad...             3
# 216  sent letter subscriber bad coverage wonder cha...             3
# 323  look way handling e mail case total mess unfit...             3
# 422  attack turning total disaster gave month notic...             3
# 499       sander bad podesta bad instinct league truth             3
# 671  weak ineffective leader bad conference call me...             3
# 677         worst fortunately bad rating everyone know             3
# 750    many must said action speak word said bad thing             3
# 787  foreign policy bad nuclear deal ransom payment...             3
# 858                            virtue show bad set con             3
#
#      VADER_score
# 155      -0.9293
# 216      -0.7925
# 323      -0.7424
# 422      -0.8020
# 499      -0.7906
# 671      -0.8155
# 677      -0.8658
# 750      -0.9080
# 787      -0.8455
# 858      -0.7027

# %%
data.loc[2155]["text"]
# Out:
# "Crooked Hillary Clinton overregulates, overtaxes and doesn't care about jobs. Most importantly, she suffers from plain old bad judgement!"

# %%
#cluster 4 nonsense
cluster4 = data.loc[data['label_kmeans'] == 4]
cluster4.count()
cluster4.hist('VADER_score', bins = 50)
plt.savefig('VADER_4nonsense.png',bbox_inches="tight")
plt.title('4 nonsense')
plt.show()

# %%
#cluster 5 nonsense
cluster5 = data.loc[data['label_kmeans'] == 5]
cluster5.count()
cluster5.hist('VADER_score', bins = 50)
plt.savefig('VADER_5nonsense.png',bbox_inches="tight")
plt.title('5 nonsense')
plt.show()

# %%
#cluster 6 interview
cluster6 = data.loc[data['label_kmeans'] == 6]
cluster6.count()
cluster6.hist('VADER_score', bins = 50)
plt.savefig('VADER_interview.png',bbox_inches="tight")
plt.title('Interview')
plt.show()

# %%
#cluster 7 #draintheswamp
cluster7 = data.loc[data['label_kmeans'] == 7]
cluster7.count()
cluster7.hist('VADER_score', bins = 50)
plt.savefig('VADER_draintheswamp.png',bbox_inches="tight")
plt.title('#draintheswamp')
plt.show()

# %%
#cluster 8 thank you/join me
cluster8 = data.loc[data['label_kmeans'] == 8]
cluster8.count()
cluster8.hist('VADER_score', bins = 50)
plt.savefig('VADER_thank.png',bbox_inches="tight")
plt.title('Thank you/join me')
plt.show()

# %% [markdown]
# 0 = big, 1 = nonsense, 2 = America,
# 3 = Hillary?, 4 = nonsense, 5 = nonsense, 6 = interview,
# 7 = #draintheswamp, 8 = thank you / join me, 9 = nonsense

# %%
#cluster 9 nonsense
cluster9 = data.loc[data['label_kmeans'] == 9]
cluster9.count()
cluster9.hist('VADER_score', bins = 50)
#plt.savefig('VADER_train.png',bbox_inches="tight")
plt.title('9 nonsense')
plt.show()

# %% [markdown]
# ### VADER on the whole dataset

# %%
data.hist('VADER_score', bins = 50)
plt.savefig('VADER_train.png',bbox_inches="tight")
plt.show()
